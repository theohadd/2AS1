# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
import requests
import pandas as pd

# URL avec les spécifications
api_url = "http://api.cquest.org/dvf?code_commune=29168&type_local=Maison"
# Conversion en disctionnaire json
req = requests.get(api_url)
wb = req.json()
# print(wb)
# print(wb.keys())

# %%
# Découpage géographique :
geo_url = 'https://geo.api.gouv.fr/communes?nom=Plogoff&fields=departement&boost=population&limit=5'
# Création d'un histogramme
L = []
for i in range(len(wb['resultats'])) : 
    L.append(wb['resultats'][i]['valeur_fonciere'])
plt.hist(L, bins=20, edgecolor='black')
plt.xlabel("Prix de transaction")
plt.ylabel("Nb de transactions")
# Out:
# Text(0, 0.5, 'Nb de transactions')
